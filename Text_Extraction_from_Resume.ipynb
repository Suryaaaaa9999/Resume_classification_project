# %% [markdown]
# ## Resume Classification
# ### Business objective:
# * The document classification solution should significantly reduce the manual human effort in the HRM. It should achieve a higher level of accuracy and automation with minimal human intervention.

# %% [markdown]
# ## 1. Import Library

# %%
# !pip install textract==1.6.3
import os
import re
import nltk
import spacy
import string
import textract
import pandas as pd
import seaborn as sns
from matplotlib import pylab
from matplotlib import pyplot as plt

from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from wordcloud import WordCloud, STOPWORDS
from nltk.stem import PorterStemmer, WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer

import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: textract==1.6.3 in /usr/local/lib/python3.11/dist-packages (1.6.3)
# Requirement already satisfied: argcomplete==1.10.0 in /usr/local/lib/python3.11/dist-packages (from textract==1.6.3) (1.10.0)
# Requirement already satisfied: beautifulsoup4==4.8.0 in /usr/local/lib/python3.11/dist-packages (from textract==1.6.3) (4.8.0)
# Requirement already satisfied: chardet==3.0.4 in /usr/local/lib/python3.11/dist-packages (from textract==1.6.3) (3.0.4)
# Requirement already satisfied: docx2txt==0.8 in /usr/local/lib/python3.11/dist-packages (from textract==1.6.3) (0.8)
# Requirement already satisfied: EbookLib==0.17.1 in /usr/local/lib/python3.11/dist-packages (from textract==1.6.3) (0.17.1)
# Requirement already satisfied: extract-msg==0.23.1 in /usr/local/lib/python3.11/dist-packages (from textract==1.6.3) (0.23.1)
# Requirement already satisfied: pdfminer.six==20181108 in /usr/local/lib/python3.11/dist-packages (from textract==1.6.3) (20181108)
# Requirement already satisfied: python-pptx==0.6.18 in /usr/local/lib/python3.11/dist-packages (from textract==1.6.3) (0.6.18)
# Requirement already satisfied: six==1.12.0 in /usr/local/lib/python3.11/dist-packages (from textract==1.6.3) (1.12.0)
# Requirement already satisfied: SpeechRecognition==3.8.1 in /usr/local/lib/python3.11/dist-packages (from textract==1.6.3) (3.8.1)
# Requirement already satisfied: xlrd==1.2.0 in /usr/local/lib/python3.11/dist-packages (from textract==1.6.3) (1.2.0)
# Requirement already satisfied: soupsieve>=1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4==4.8.0->textract==1.6.3) (2.7)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from EbookLib==0.17.1->textract==1.6.3) (5.4.0)
# Requirement already satisfied: imapclient==2.1.0 in /usr/local/lib/python3.11/dist-packages (from extract-msg==0.23.1->textract==1.6.3) (2.1.0)
# Requirement already satisfied: olefile==0.46 in /usr/local/lib/python3.11/dist-packages (from extract-msg==0.23.1->textract==1.6.3) (0.46)
# Requirement already satisfied: tzlocal==1.5.1 in /usr/local/lib/python3.11/dist-packages (from extract-msg==0.23.1->textract==1.6.3) (1.5.1)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20181108->textract==1.6.3) (3.23.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20181108->textract==1.6.3) (2.4.0)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.11/dist-packages (from python-pptx==0.6.18->textract==1.6.3) (11.2.1)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /usr/local/lib/python3.11/dist-packages (from python-pptx==0.6.18->textract==1.6.3) (3.2.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.11/dist-packages (from tzlocal==1.5.1->extract-msg==0.23.1->textract==1.6.3) (2025.2)

# %% [markdown]
# ## 2. Exctract the Text from Dataset

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
os.listdir('/content/drive/MyDrive/Resumes')
# Out:
# ['workday resumes',
#  'SQL Developer Lightning insight',
#  'Peoplesoft resumes',
#  'Internship',
#  'Reactjs developer']

# %%
# !apt-get install antiword
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# antiword is already the newest version (0.37-16).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %% [raw]
# # try to extract all folder one time
# import os
#
# file_name = []
# category = []
# base_dir = './Resume_Docx'
# for root, dirs, files in os.walk(base_dir, topdown=False):
#     for name in files:
#         if name.endswith(".docx"):
#             file_path = os.path.join(root, name)
#             file_name.append(file_path)

# %%
file_path1 = []
category1  = []
directory1 = r'/content/drive/MyDrive/Resumes/Peoplesoft resumes'
for i in os.listdir(directory1):
    if i.endswith(('.docx','.doc')):
        os.path.join(directory1, i)
        file_path1.append((textract.process(os.path.join(directory1, i))).decode('utf-8'))
        category1.append('PeopleSoft')

# %%
data1 = pd.DataFrame(data = file_path1 , columns = ['Raw_Details'])
data1['Category1'] = category1
data1
# Out:
#                                           Raw_Details   Category1
# 0   \n                          PEOPLESOFT Adminis...  PeopleSoft
# 1   SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...  PeopleSoft
# 2   \n\n\n\n\n\n\n\n\nProfile Summary:\n • 7+ year...  PeopleSoft
# 3   Classification: Internal\n\nClassification: In...  PeopleSoft
# 4   \nVinod Akkala\nPeopleSoft DBA Admin.\n\n\nPro...  PeopleSoft
# 5   Hari Narayana \t\t              \n\n\t\n\n\n\n...  PeopleSoft
# 6   \n|Personal Details                           ...  PeopleSoft
# 7   Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...  PeopleSoft
# 8   \nArun Venu\n\n\n  EXPERIENCE SUMMARY\n\n\n   ...  PeopleSoft
# 9   Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...  PeopleSoft
# 10  \nRahul Ahuja\n-------------------------------...  PeopleSoft
# 11  Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...  PeopleSoft
# 12  \n\nR Ahmed\n                          PeopleS...  PeopleSoft
# 13  Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...  PeopleSoft
# 14  PeopleSoft Administration\n\n \n\nVivekanand S...  PeopleSoft
# 15  \n                        PeopleSoft Admin/Peo...  PeopleSoft
# 16  C O N T A C T :\n\n\n\nAddress: Manyata Tech P...  PeopleSoft
# 17  \n                      PeopleSoft Database Ad...  PeopleSoft
# 18  PeopleSoft Admin\n\nVARKALA VIKAS\n\n\n\nCaree...  PeopleSoft
# 19  \nPriyanka Ramadoss\n\n61/46, MountPleasant,\n...  PeopleSoft

# %%
file_path2 = []
category2  = []
directory2 = r'/content/drive/MyDrive/Resumes/Reactjs developer'
for i in os.listdir(directory2):
    if i.endswith(('.docx','.doc','.pdf')):
        os.path.join(directory2, i)
        file_path2.append((textract.process(os.path.join(directory2, i))).decode('utf-8'))
        category2.append('React JS Developer')

# %%
data2 = pd.DataFrame(data = file_path2 , columns = ['Raw_Details'])
data2['Category2'] = category2
data2
# Out:
#                                           Raw_Details           Category2
# 0   KAMALAKAR REDDY. A \n\nLinked In: https://www....  React JS Developer
# 1   Naveen Sadhu\n\n\n\n\n\nTitle: software develo...  React JS Developer
# 2   MAREEDU LOKESH BABU\n\n\n\nPROFESSIONAL OVERVI...  React JS Developer
# 3   Ui-Developer/ React JS Developer \n\nNAME: KRI...  React JS Developer
# 4   SHAIK ABDUL SHARUK   \n\n2 years’ Experience i...  React JS Developer
# 5   Pranish Sonone\n\n\t\t\n\n\n\n\n\n\n\n\n\nCare...  React JS Developer
# 6   Venkatalakshmi Pedireddy\n\nSoftware Developer...  React JS Developer
# 7   \nMaryala Vinay Reddy\n\nProfessional Summary:...  React JS Developer
# 8   MD KHIZARUDDIN RAUF \n\n \t EXPERIENCE \n\n   ...  React JS Developer
# 9   PRAGNYA PATTNAIK\n\n \n\n \n\n \n\n Expertise:...  React JS Developer
# 10  \n                              CURRICULUM VIT...  React JS Developer
# 11  Kotani Durga Prasad\n\n\n\n\n\nObjective:\n\n\...  React JS Developer
# 12   \n\n \n\n \n\nName: M. Prabakaran \nTitle: UI...  React JS Developer
# 13  Kanumuru Deepak Reddy\n\n\n\n\t\n\n\n\nCAREER ...  React JS Developer
# 14  Ui-Developer/ React JS Developer \n\nNAME: KRI...  React JS Developer
# 15  \n [pic]\n\nPROFILE\n\n Searching for the oppo...  React JS Developer
# 16  Ranga Gaganam  \n\n\n\n \n\nProfessional\n\n \...  React JS Developer
# 17  MAREEDU LOKESH BABU\n\nPROFESSIONAL OVERVIEW\n...  React JS Developer
# 18  KAMBALA SAI SURENDRA   \n\n \n\n \n\n \n\n\n\n...  React JS Developer
# 19  HARIPRIYA BATTINA \n\nExperience as UI Develop...  React JS Developer
# 20  SARALA MADASU\n\nSARALA MADASU\n\n 204,Sri ge...  React JS Developer
# 21  Thirupathamma Balla\n\n\n\nSUMMARY:\n\n\n\n2.8...  React JS Developer
# 22  Name: M. Prabakaran \nTitle: UI Developer\n\nP...  React JS Developer

# %%
file_path3 = []
category3  = []
directory3 = r'/content/drive/MyDrive/Resumes/SQL Developer Lightning insight'
for i in os.listdir(directory3):
    if i.endswith(('.docx','.doc')):
        os.path.join(directory3, i)
        file_path3.append((textract.process(os.path.join(directory3, i))).decode('utf-8'))
        category3.append('SQL Developer')

# %%
data3 = pd.DataFrame(data = file_path3 , columns = ['Raw_Details'])
data3['Category3'] = category3
data3
# Out:
#                                           Raw_Details      Category3
# 0   SQL DEVELOPER\n\nName: -   Bandi prem sai\n\n\...  SQL Developer
# 1   \n\n\n\n\n “ Hyderabad\nNazeer Basha\n SQL and...  SQL Developer
# 2   RAJU PAVANA KUMARI\n\n\n\n\t\n\n\tProfessional...  SQL Developer
# 3   Name: Ramesh\n\n\t\n\n\tCareer Objective: \n\n...  SQL Developer
# 4   ANIL KUMAR MADDUKURI  \t\t\n\nSQL & MSBI Devel...  SQL Developer
# 5   BUDDHA VAMSI                                  ...  SQL Developer
# 6   \n                                       SQL S...  SQL Developer
# 7   SQL AND MSBI DEVELOPER\n\nSQL AND MSBI DEVELOP...  SQL Developer
# 8   KAMBALLA PRADEEP                              ...  SQL Developer
# 9   SQL SERVER DEVELOPER\n\n\n\n\n\nP. Syam Kumar ...  SQL Developer
# 10  Resume\n\nName     :  Neeraj Mishra\n\n\n\nExp...  SQL Developer
# 11  Aradhana Tripathi\n\n\n\nCurrent Location: Gac...  SQL Developer
# 12  \n\nCareer objective\n\n\nA rewarding opportun...  SQL Developer
# 13  resume\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\t\t\tRama...  SQL Developer

# %%
file_path4 = []
category4  = []
directory4 = r'/content/drive/MyDrive/Resumes/workday resumes'
for i in os.listdir(directory4):
     if i.endswith(('.docx','.doc')):
        os.path.join(directory4, i)
        file_path4.append((textract.process(os.path.join(directory4, i))).decode('utf-8'))
        category4.append('Workday')

# %%
data4 = pd.DataFrame(data = file_path4 , columns = ['Raw_Details'])
data4['Category4'] = category4
data4
# Out:
#                                           Raw_Details Category4
# 0   WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...   Workday
# 1   VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...   Workday
# 2   JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...   Workday
# 3   Workday HCM  Techno functional Consultant     ...   Workday
# 4   \n\n                             Madeeswar A\n...   Workday
# 5   \nHIMA.MENDU\n\n\n\nCareer Objective\nTo conti...   Workday
# 6   \n[pic]                                   Name...   Workday
# 7   \nShireesh                                    ...   Workday
# 8   Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...   Workday
# 9   \n      Workday Integration Consultant\n\nName...   Workday
# 10  Mooraboyina Guravaiah\n\nWorkday Integration S...   Workday
# 11  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...   Workday
# 12  Vinay kumar .v\nWorkday Functional Consultant\...   Workday
# 13  G Himaja\n\n                                  ...   Workday
# 14  \nVenkateswarlu.B                             ...   Workday
# 15  \nHarikrishna Akula\n\n\n\n Summary:\n    ❖ 5....   Workday
# 16  \n                               Hari Krishna ...   Workday
# 17  \nName  : Naresh Babu Cherukuri\n\n\nObjective...   Workday
# 18  \n  [pic]\n  [pic]\n\n    • 3.3 years of IT ex...   Workday
# 19  Srikanth (WORKDAY hCM Consultant)\t           ...   Workday
# 20  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...   Workday

# %%
file_path5 = []
category5  = []
directory5 = r'/content/drive/MyDrive/Resumes/Internship'
for i in os.listdir(directory5):
     if i.endswith(('.docx','.doc')):
        os.path.join(directory5, i)
        file_path5.append((textract.process(os.path.join(directory5, i))).decode('utf-8'))
        category5.append('Internship')

# %%
data5 = pd.DataFrame(data = file_path5 , columns = ['Raw_Details'])
data5['Category5'] = category5
data5
# Out:
#                                          Raw_Details   Category5
# 0  Name: Ravali P \n\n\n\n                       ...  Internship
# 1  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...  Internship

# %% [markdown]
# ## 3. Create a DataFrame

# %%
resume_data = pd.concat([data1, data2, data3, data4,data5], ignore_index=True)
resume_data
# Out:
#                                           Raw_Details   Category1 Category2  \
# 0   \n                          PEOPLESOFT Adminis...  PeopleSoft       NaN
# 1   SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...  PeopleSoft       NaN
# 2   \n\n\n\n\n\n\n\n\nProfile Summary:\n • 7+ year...  PeopleSoft       NaN
# 3   Classification: Internal\n\nClassification: In...  PeopleSoft       NaN
# 4   \nVinod Akkala\nPeopleSoft DBA Admin.\n\n\nPro...  PeopleSoft       NaN
# ..                                                ...         ...       ...
# 75  \n  [pic]\n  [pic]\n\n    • 3.3 years of IT ex...         NaN       NaN
# 76  Srikanth (WORKDAY hCM Consultant)\t           ...         NaN       NaN
# 77  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...         NaN       NaN
# 78  Name: Ravali P \n\n\n\n                       ...         NaN       NaN
# 79  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...         NaN       NaN
#
#    Category3 Category4   Category5
# 0        NaN       NaN         NaN
# 1        NaN       NaN         NaN
# 2        NaN       NaN         NaN
# 3        NaN       NaN         NaN
# 4        NaN       NaN         NaN
# ..       ...       ...         ...
# 75       NaN   Workday         NaN
# 76       NaN   Workday         NaN
# 77       NaN   Workday         NaN
# 78       NaN       NaN  Internship
# 79       NaN       NaN  Internship
#
# [80 rows x 6 columns]

# %%
resume_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Raw_Details  80 non-null     object
#  1   Category1    20 non-null     object
#  2   Category2    23 non-null     object
#  3   Category3    14 non-null     object
#  4   Category4    21 non-null     object
#  5   Category5    2 non-null      object
# dtypes: object(6)
# memory usage: 3.9+ KB

# %% [markdown]
# ### 3.1 Merge all Unnecessary column in One Column

# %%
resume_data['Category'] = category1 + category2 + category3 + category4+ category5
resume_data
# Out:
#                                           Raw_Details   Category1 Category2  \
# 0   \n                          PEOPLESOFT Adminis...  PeopleSoft       NaN
# 1   SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...  PeopleSoft       NaN
# 2   \n\n\n\n\n\n\n\n\nProfile Summary:\n • 7+ year...  PeopleSoft       NaN
# 3   Classification: Internal\n\nClassification: In...  PeopleSoft       NaN
# 4   \nVinod Akkala\nPeopleSoft DBA Admin.\n\n\nPro...  PeopleSoft       NaN
# ..                                                ...         ...       ...
# 75  \n  [pic]\n  [pic]\n\n    • 3.3 years of IT ex...         NaN       NaN
# 76  Srikanth (WORKDAY hCM Consultant)\t           ...         NaN       NaN
# 77  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...         NaN       NaN
# 78  Name: Ravali P \n\n\n\n                       ...         NaN       NaN
# 79  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...         NaN       NaN
#
#    Category3 Category4   Category5    Category
# 0        NaN       NaN         NaN  PeopleSoft
# 1        NaN       NaN         NaN  PeopleSoft
# 2        NaN       NaN         NaN  PeopleSoft
# 3        NaN       NaN         NaN  PeopleSoft
# 4        NaN       NaN         NaN  PeopleSoft
# ..       ...       ...         ...         ...
# 75       NaN   Workday         NaN     Workday
# 76       NaN   Workday         NaN     Workday
# 77       NaN   Workday         NaN     Workday
# 78       NaN       NaN  Internship  Internship
# 79       NaN       NaN  Internship  Internship
#
# [80 rows x 7 columns]

# %%
resume_data.drop(['Category1', 'Category2', 'Category3', 'Category4','Category5'], axis = 1, inplace = True)
resume_data = resume_data[["Category", "Raw_Details"]]

# %% [markdown]
# ### 3.2 Final Dataset

# %%
resume_data.head(15)
# Out:
#       Category                                        Raw_Details
# 0   PeopleSoft  \n                          PEOPLESOFT Adminis...
# 1   PeopleSoft  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...
# 2   PeopleSoft  \n\n\n\n\n\n\n\n\nProfile Summary:\n • 7+ year...
# 3   PeopleSoft  Classification: Internal\n\nClassification: In...
# 4   PeopleSoft  \nVinod Akkala\nPeopleSoft DBA Admin.\n\n\nPro...
# 5   PeopleSoft  Hari Narayana \t\t              \n\n\t\n\n\n\n...
# 6   PeopleSoft  \n|Personal Details                           ...
# 7   PeopleSoft  Murali\t\t       \n\n\t\n\n\n\n\n\n\n\n\n\n\n\...
# 8   PeopleSoft  \nArun Venu\n\n\n  EXPERIENCE SUMMARY\n\n\n   ...
# 9   PeopleSoft  Anubhav Kumar Singh\t\t\n\n\n\nCore Competenci...
# 10  PeopleSoft  \nRahul Ahuja\n-------------------------------...
# 11  PeopleSoft  Tanna Sujatha \n\n\n\n\n\n\n\nOBJECTIVE\n\nSee...
# 12  PeopleSoft  \n\nR Ahmed\n                          PeopleS...
# 13  PeopleSoft  Priyabrata Hota\n\n\n\n\n\nCAREER OBJECTIVE\t\...
# 14  PeopleSoft  PeopleSoft Administration\n\n \n\nVivekanand S...

# %%
resume_data["Raw_Details"][4]
# Out:
# '\nVinod Akkala\nPeopleSoft DBA Admin.\n\n\nProfessional Summary:\n\n  ➢ Having 7+years of experience in PeopleSoft Admin/Dba implementation and\n    Supporting PeopleSoft applications Like HCM/FSCM modules on Oracle\n    Database and their supporting operating systems.\n  ➢ Implementing PeopleSoft Internet architecture(PIA) on\n    Demo,Dev,Test,Production Instances.\n  ➢ Experience in configuration of Application Server Domains and Process\n    Scheduler Setup.\n  ➢ Performed Installation, configuration and maintained Oracle 10g/11g/12C\n    databases on UNIX, Linux and NT Servers.\n  ➢ Experience in Project Migration and Data Migration.\n  ➢ Experience in generating Compare Reports between various environments.\n  ➢ Worked on applying Patches, Bundles and Tax Updates.\n  ➢ Configuring Change Assistant to apply Bundles and Tax updates.\n  ➢ Maintaining integrity and internal consistency of the database using\n    DDDAUDIT, SYSAUDIT, ALTERAUDIT reports periodically.\n  ➢ Experienced in Integration Broker setup.\n  ➢ Worked on applying Patches, Bundles and Tax Updates using Change\n    Assistant and PeopleSoft Update Manager (PUM).\n  ➢ Experience on  People Tools Upgrade.\n  ➢ Experience on IB.\n  ➢ Experience on PeopleSoft Refreshes.\n  ➢ Experience on PeopleSoft Security.\n  ➢ Experienced in COBOL Compilation on Windows and Linux.\n  ➢ Experience in load balancing of Application server domains and Process\n    Scheduler Server domains.\n  ➢ Installed People Books and configured the Web Server to access People\n    Books.\n  ➢ Experience in Troubleshooting of various servers like Application\n    Servers, Web Servers, and Process Scheduler Servers.\n  ➢ Involved in Regular Backup/Recovery of Oracle Database including\n    Logical & Physical Backups.\n  ➢ Experience in Applying Database Patches.\n  ➢ Working on Capacity Planning For Table Spaces.\n  ➢ Experience in Applying Database Upgrading.\n  ➢ Experience in installing, maintaining, Upgrading, Migrating and\n    Patching Oracle versions 10g/11g/12c.\n  ➢ Experience in Database refreshes.\n  ➢ Experience on Linux Admin.\n  ➢ Experience in Rman configuration.\n  ➢ Experience in Database Security Management: Users, Roles, Profile.\n  ➢ Taking Hot and cold Backups.\n  ➢ Experience in resolving developer issues like Resetting Passwords.\n  ➢ Supporting role in Database Cloning.\n  ➢ Managing the size and file of the Table spaces and adding Data files to\n    Table Spaces.\n  ➢ Experience in multiplexing of Control files.\n  ➢ Experience in Data pump Technology.\n  ➢ Experience in Tuning of Application Server Domains, Process Scheduler\n    Domains and Web Server Domains.\n\n\nKEY SKILS\n\n\n    |                  TECHNOLOGY        |                  TOOLS             |\n|ERP TOOLS                           |PeopleTools8.54/8.53/8.50,ChangeAssi|\n|                                    |stant, IntegrationBroker,           |\n|                                    |ApplicationDesigner,Configuration   |\n|                                    |Manager, PeopleSoft Update Manager  |\n|                                    |(PUM), and Data Mover.              |\n|APPLICATIONS                        |PeopleSoft HRMS/FSCM/CRM 9.0/9.1/9.2|\n|APPLICATION SERVER                  |Tuxedo 10.3./12c                    |\n|WEB SERVER                          |Web Logic 10.3/12c                  |\n|OPERATING SYSTEMS                   |Windows Server 2012 R2/2008 R2/2003 |\n|                                    |Red hat Enterprise Linux 5/6        |\n|                                    |Oracle Enterprise Linux 5.4/6/7     |\n|DATABASE                            |Oracle 10gR2/11gR2/12c              |\n\n\n\n\nEDUCATIONAL QUALIFICATION\n\n\nM.ca.(Masterof  Computer  Application)  from  Sri  Venkateswara  University,\nTirupati in 2012 with (75%), Andhra Pradesh.\n\n\n\nPROFESSIONAL EXPERIENCE\n\n\n    ➢ Working as PeopleSoft Database Administrator with Infosys  At\n      Bangalore from May 2020 to Till D ...

# %% [markdown]
# ### 3.3 Save new CSV File

# %%
resume_data.to_csv('Raw_Resume.csv', index=False)

# %% [markdown]
# ## 4. Data Understanding

# %%
resume_data = pd.read_csv("Raw_Resume.csv")
resume_data
# Out:
#       Category                                        Raw_Details
# 0   PeopleSoft  \n                          PEOPLESOFT Adminis...
# 1   PeopleSoft  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...
# 2   PeopleSoft  \n\n\n\n\n\n\n\n\nProfile Summary:\n • 7+ year...
# 3   PeopleSoft  Classification: Internal\n\nClassification: In...
# 4   PeopleSoft  \nVinod Akkala\nPeopleSoft DBA Admin.\n\n\nPro...
# ..         ...                                                ...
# 75     Workday  \n  [pic]\n  [pic]\n\n    • 3.3 years of IT ex...
# 76     Workday  Srikanth (WORKDAY hCM Consultant)\t           ...
# 77     Workday  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 78  Internship  Name: Ravali P \n\n\n\n                       ...
# 79  Internship  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...
#
# [80 rows x 2 columns]

# %%
resume_data[resume_data.Category == 'Workday']
# Out:
#    Category                                        Raw_Details
# 57  Workday  WORKDAY | HCM | FCM\n\nName \t\t: Kumar S.S\n\...
# 58  Workday  VENKATA SAIKRISHNA\n\n Workday Consultant\n\n\...
# 59  Workday  JYOTI VERMA\t\t\t\t\t\n\n\n\nPROFESSIONAL SUMM...
# 60  Workday  Workday HCM  Techno functional Consultant     ...
# 61  Workday  \n\n                             Madeeswar A\n...
# 62  Workday  \nHIMA.MENDU\n\n\n\nCareer Objective\nTo conti...
# 63  Workday  \n[pic]                                   Name...
# 64  Workday  \nShireesh                                    ...
# 65  Workday  Name         : Gopi Krishna Reddy\n\n\t\t\t\t ...
# 66  Workday  \n      Workday Integration Consultant\n\nName...
# 67  Workday  Mooraboyina Guravaiah\n\nWorkday Integration S...
# 68  Workday  Chinna Subbarayudu M\n\nDOB: 06th March 1994\n...
# 69  Workday  Vinay kumar .v\nWorkday Functional Consultant\...
# 70  Workday  G Himaja\n\n                                  ...
# 71  Workday  \nVenkateswarlu.B                             ...
# 72  Workday  \nHarikrishna Akula\n\n\n\n Summary:\n    ❖ 5....
# 73  Workday  \n                               Hari Krishna ...
# 74  Workday  \nName  : Naresh Babu Cherukuri\n\n\nObjective...
# 75  Workday  \n  [pic]\n  [pic]\n\n    • 3.3 years of IT ex...
# 76  Workday  Srikanth (WORKDAY hCM Consultant)\t           ...
# 77  Workday  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...

# %%
resume_data.isnull().sum()
# Out:
# Category       0
# Raw_Details    0
# dtype: int64

# %% [markdown]
# ### 4.1 Number of Words in each Resume

# %%
resume_data['Word_Count'] = resume_data['Raw_Details'].apply(lambda x: len(str(x).split(" ")))
resume_data[['Raw_Details','Word_Count']].head()
# Out:
#                                          Raw_Details  Word_Count
# 0  \n                          PEOPLESOFT Adminis...        4965
# 1  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...         455
# 2  \n\n\n\n\n\n\n\n\nProfile Summary:\n • 7+ year...        2189
# 3  Classification: Internal\n\nClassification: In...         558
# 4  \nVinod Akkala\nPeopleSoft DBA Admin.\n\n\nPro...        4615

# %% [markdown]
# ### 4.2 Number of Characters

# %%
resume_data['Char_Count'] = resume_data['Raw_Details'].str.len() ## this also includes spaces
resume_data[['Raw_Details','Char_Count']].head()
# Out:
#                                          Raw_Details  Char_Count
# 0  \n                          PEOPLESOFT Adminis...       21007
# 1  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...        3800
# 2  \n\n\n\n\n\n\n\n\nProfile Summary:\n • 7+ year...        8847
# 3  Classification: Internal\n\nClassification: In...        4917
# 4  \nVinod Akkala\nPeopleSoft DBA Admin.\n\n\nPro...       16983

# %% [markdown]
# ### 4.3 Number of Stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
resume_data['Stopwords'] = resume_data['Raw_Details'].apply(lambda x: len([x for x in x.split() if x in stop]))
resume_data[['Raw_Details','Stopwords']].head()
# Out:
#                                          Raw_Details  Stopwords
# 0  \n                          PEOPLESOFT Adminis...        640
# 1  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...         86
# 2  \n\n\n\n\n\n\n\n\nProfile Summary:\n • 7+ year...        186
# 3  Classification: Internal\n\nClassification: In...        114
# 4  \nVinod Akkala\nPeopleSoft DBA Admin.\n\n\nPro...        356

# %% [markdown]
# ### 4.4 Number of Numerics

# %%
resume_data['Numerics'] = resume_data['Raw_Details'].apply(lambda x: len([x for x in x.split() if x.isdigit()]))
resume_data[['Raw_Details','Numerics']].head()
# Out:
#                                          Raw_Details  Numerics
# 0  \n                          PEOPLESOFT Adminis...        10
# 1  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...        15
# 2  \n\n\n\n\n\n\n\n\nProfile Summary:\n • 7+ year...         6
# 3  Classification: Internal\n\nClassification: In...         7
# 4  \nVinod Akkala\nPeopleSoft DBA Admin.\n\n\nPro...        18

# %%
resume_data
# Out:
#       Category                                        Raw_Details  Word_Count  \
# 0   PeopleSoft  \n                          PEOPLESOFT Adminis...        4965
# 1   PeopleSoft  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...         455
# 2   PeopleSoft  \n\n\n\n\n\n\n\n\nProfile Summary:\n • 7+ year...        2189
# 3   PeopleSoft  Classification: Internal\n\nClassification: In...         558
# 4   PeopleSoft  \nVinod Akkala\nPeopleSoft DBA Admin.\n\n\nPro...        4615
# ..         ...                                                ...         ...
# 75     Workday  \n  [pic]\n  [pic]\n\n    • 3.3 years of IT ex...        1283
# 76     Workday  Srikanth (WORKDAY hCM Consultant)\t           ...        1063
# 77     Workday  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...         716
# 78  Internship  Name: Ravali P \n\n\n\n                       ...        1795
# 79  Internship  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...         533
#
#     Char_Count  Stopwords  Numerics
# 0        21007        640        10
# 1         3800         86        15
# 2         8847        186         6
# 3         4917        114         7
# 4        16983        356        18
# ..         ...        ...       ...
# 75        5332        141         3
# 76        6737        194         9
# 77        5951        161         1
# 78        6175        179        12
# 79        1901         39         0
#
# [80 rows x 6 columns]

# %% [markdown]
# ## 5. Text Pre-Processing

# %% [markdown]
# ### 5.1 Using Regular Expression

# %%
def preprocess(sentence):
    sentence = str(sentence)
    sentence = sentence.lower()
    sentence = sentence.replace('{html}',"")
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, '', sentence)
    rem_url = re.sub(r'http\S+', '',cleantext)
    rem_num = re.sub('[0-9]+', '', rem_url)
    tokenizer = RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(rem_num)
    filtered_words = [w for w in tokens if len(w) > 2 if not w in stopwords.words('english')]

    return " ".join(filtered_words)

# %%
resume_data = pd.read_csv('Raw_Resume.csv')
resume_data['Resume_Details'] = resume_data.Raw_Details.apply(lambda x: preprocess(x))

# %% [markdown]
# ### 5.2 Clean Text from Resume

# %%
resume_data
# Out:
#       Category                                        Raw_Details  \
# 0   PeopleSoft  \n                          PEOPLESOFT Adminis...
# 1   PeopleSoft  SIRAZUDDIN M\n\n\tBangalore, INDIA\t\n\n\n\n\n...
# 2   PeopleSoft  \n\n\n\n\n\n\n\n\nProfile Summary:\n • 7+ year...
# 3   PeopleSoft  Classification: Internal\n\nClassification: In...
# 4   PeopleSoft  \nVinod Akkala\nPeopleSoft DBA Admin.\n\n\nPro...
# ..         ...                                                ...
# 75     Workday  \n  [pic]\n  [pic]\n\n    • 3.3 years of IT ex...
# 76     Workday  Srikanth (WORKDAY hCM Consultant)\t           ...
# 77     Workday  Ramesh A\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t...
# 78  Internship  Name: Ravali P \n\n\n\n                       ...
# 79  Internship  SUSOVAN  BAG   \n\nSeeking  a  challenging  po...
#
#                                        Resume_Details
# 0   peoplesoft administrator srinivas experience s...
# 1   sirazuddin bangalore india sirazuddin bangalor...
# 2   profile summary years experience implementing ...
# 3   classification internal classification interna...
# 4   vinod akkala peoplesoft dba admin professional...
# ..                                                ...
# 75  pic pic years experience workday hcm technical...
# 76  srikanth workday hcm consultant seeking suitab...
# 77  ramesh workday hcm consultant professional sum...
# 78  name ravali curriculum vitae specialization co...
# 79  susovan bag seeking challenging position field...
#
# [80 rows x 3 columns]

# %% [markdown]
# ### 5.3 Save the Clean Data in new CSV File

# %%
resume_data.drop(['Raw_Details'], axis = 1, inplace = True)
resume_data
# Out:
#       Category                                     Resume_Details
# 0   PeopleSoft  peoplesoft administrator srinivas experience s...
# 1   PeopleSoft  sirazuddin bangalore india sirazuddin bangalor...
# 2   PeopleSoft  profile summary years experience implementing ...
# 3   PeopleSoft  classification internal classification interna...
# 4   PeopleSoft  vinod akkala peoplesoft dba admin professional...
# ..         ...                                                ...
# 75     Workday  pic pic years experience workday hcm technical...
# 76     Workday  srikanth workday hcm consultant seeking suitab...
# 77     Workday  ramesh workday hcm consultant professional sum...
# 78  Internship  name ravali curriculum vitae specialization co...
# 79  Internship  susovan bag seeking challenging position field...
#
# [80 rows x 2 columns]

# %%
resume_data.to_csv('Cleaned_Resumes.csv', index = False)

# %%
resume_data = pd.read_csv('Cleaned_Resumes.csv')
resume_data
# Out:
#       Category                                     Resume_Details
# 0   PeopleSoft  peoplesoft administrator srinivas experience s...
# 1   PeopleSoft  sirazuddin bangalore india sirazuddin bangalor...
# 2   PeopleSoft  profile summary years experience implementing ...
# 3   PeopleSoft  classification internal classification interna...
# 4   PeopleSoft  vinod akkala peoplesoft dba admin professional...
# ..         ...                                                ...
# 75     Workday  pic pic years experience workday hcm technical...
# 76     Workday  srikanth workday hcm consultant seeking suitab...
# 77     Workday  ramesh workday hcm consultant professional sum...
# 78  Internship  name ravali curriculum vitae specialization co...
# 79  Internship  susovan bag seeking challenging position field...
#
# [80 rows x 2 columns]

# %%
resume_data.Resume_Details[5]
# Out:
# 'hari narayana professional summary years experience peoplesoft application enhancement implementation data conversion support upgrade projects well experienced people tools functional knowledge hcm fscm applications skill people tools application designer application engine people code application packages peoplesoft application fscm hcm applications fscm modules procurement billing hcm modules recruiting performance management waf benefits interfaces component interface file layout languages database oracle sql server operating system windows unix education bachelor technology tech jntu currently working people soft consultant randstad hyderabad relevant experience peoplesoft consultant randstad hyderabad andhra pradesh india june till date project randstad enhancements client randstad staffing responsibilities analyze requirement documents understand customer business requirement provide technical approach fdd assign customize system applications designed many objects scratch write people code implement business logic design custom application engine programs process data design application engine programs send notifications responsible prepare unit test cases technical design documents responsible support sit uat environment people tools application designer application engine people code component interface application packages peoplesoft hcm oracle windows technical associate verizon hyderabad andhra pradesh india dec may project verizon wireless development client verizon responsibilities analyze requirement documents understand customer business requirement provide technical approach fdd assign customize system applications designed many objects scratch write people code implement business logic design custom application engine programs process data design application engine programs send notifications implemented component interface program load data people soft used file layout inbound programs responsible prepare unit test cases technical design documents responsible support sit uat environment people tools application designer application engine people code component interface application packages peoplesoft fscm oracle windows software engineer hsbc hyderabad india aug nov project hsbc upgrade project client hsbc bank responsibilities analysis understand source target system business process compare objects source targets identify changes retrofit objects based compare reports unit testing prepare unit test cases retrofit design development new modifications required customer prepared technical design documents retrofit enhancement add new text catalogues various languages responsible overseeing quality procedures related project responsible move objects development sit environment environment people tools application designer application engine people code peoplesoft hcm windows unix page page page page ciber inc rights reserved ciber inc rights reserved'

# %% [markdown]
# ## 6. Named Entity Recognition (NER)

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
oneSetOfStopWords = set(stopwords.words('english')+['``',"''"])
totalWords =[]
Sentences = resume_data['Resume_Details'].values
cleanedSentences = ""
for records in Sentences:
    cleanedText = preprocess(records)
    cleanedSentences += cleanedText
    requiredWords = nltk.word_tokenize(cleanedText)
    for word in requiredWords:
        if word not in oneSetOfStopWords and word not in string.punctuation:
            totalWords.append(word)

wordfreqdist = nltk.FreqDist(totalWords)
mostcommon = wordfreqdist.most_common(50)
print(mostcommon)
# Out:
# [('experience', 602), ('peoplesoft', 453), ('workday', 431), ('application', 419), ('using', 401), ('server', 359), ('project', 335), ('data', 332), ('reports', 326), ('sql', 280), ('business', 273), ('web', 250), ('database', 243), ('process', 236), ('worked', 220), ('knowledge', 217), ('client', 201), ('involved', 194), ('system', 193), ('tools', 190), ('integrations', 189), ('like', 183), ('integration', 183), ('hcm', 182), ('support', 178), ('skills', 173), ('development', 171), ('team', 170), ('good', 169), ('creating', 164), ('working', 162), ('services', 161), ('technical', 160), ('people', 160), ('design', 157), ('report', 155), ('servers', 152), ('created', 151), ('react', 151), ('testing', 150), ('role', 148), ('various', 146), ('developer', 144), ('oracle', 142), ('environment', 139), ('responsibilities', 137), ('management', 136), ('security', 134), ('eib', 134), ('production', 133)]

# %% [markdown]
# ## 7. Parts Of Speech (POS) Tagging

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.8.0/en_core_web_lg-3.8.0-py3-none-any.whl (400.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 1.3 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
nlp = spacy.load('en_core_web_lg')
one_block = cleanedSentences[1300:5200]
doc_block = nlp(one_block)
spacy.displacy.render(doc_block, style= 'ent', jupyter= True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">bol installation troubleshooting compiling cobol issues performed integration broker setup
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  modules worked instance verification test data refresh production ensuring data integrity using tools
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     dddaudit sysaudit development
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  phases helped create implement security server administration procedures
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sql oracle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  databases developed functional technical specifications performed administrative duties worked autosys scheduling process
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monthly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  maintenance activities like cleaning application web process scheduler servers experienced people tool upgrade knowledge application upgrade experienced monitoring
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     peoplesoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  jobs
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tivoli job
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  scheduling console tool creating new jobs scheduling jobs per requirement troubleshooting issues training junior employees
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     peoplesoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  administration related tasks handled project migrations security requests per work orders sent ticketing system performed refreshing source target databases
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     peoplesoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  experience online offline cloning servers adaptive cloud strategies based
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aws
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  experience
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aws
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  cloud platform features includes
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vpc ebs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  cloud watch load balancers iam qualification bachelor technology
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  jntu
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lenora college egg andhrapradesh year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  technical skills
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     peoplesoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     peoplesoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  applications people tools version application designer application engine people code data mover process scheduler
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     peoplesoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pum images sqr
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  query xml publisher reporting tools weblogic
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weblogic tuxedo tuxedo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  databases
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     oracle oracle oracle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  operating
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     windows unix linux systems
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  work experience currently working
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     peoplesoft
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     admin tech mahindra mahindra satyam

# %%
for token in doc_block[:30]:
    print(token,token.pos_)
# Out:
# bol NOUN
# installation NOUN
# troubleshooting NOUN
# compiling VERB
# cobol NOUN
# issues NOUN
# performed VERB
# integration NOUN
# broker NOUN
# setup NOUN
# two NUM
# modules NOUN
# worked VERB
# instance NOUN
# verification NOUN
# test NOUN
# data NOUN
# refresh VERB
# production NOUN
# ensuring VERB
# data NOUN
# integrity NOUN
# using VERB
# tools NOUN
# dddaudit NOUN
# sysaudit NOUN
# development NOUN
# phases NOUN
# helped VERB
# create VERB

# %% [markdown]
# ### 7.1 Filtering out only the Nouns and Verbs from the Text to Tokens

# %%
one_block = cleanedSentences
doc_block = nlp(one_block)
nouns_verbs = [token.text for token in doc_block if token.pos_ in ('NOUN','VERB')]
print(nouns_verbs[:250])
# Out:
# ['administrator', 'summary', 'years', 'experience', 'peoplesoft', 'administrator', 'experience', 'installations', 'configurations', 'security', 'system', 'administration', 'implementing', 'supporting', 'database', 'administration', 'dba', 'including', 'resource', 'management', 'system', 'hrms', 'systems', 'knowledge', 'experience', 'administrating', 'server', 'components', 'peoplesoft', 'application', 'servers', 'process', 'scheduler', 'servers', 'tuxedo', 'web', 'logic', 'internet', 'architecture', 'application', 'messaging', 'integration', 'broker', 'application', 'issues', 'issues', 'installing', 'administering', 'peoplesoft', 'software', 'configuring', 'workstations', 'application', 'server', 'process', 'scheduler', 'tuxedo', 'web', 'servers', 'report', 'repository', 'report', 'nodes', 'peoplesoft', 'applications', 'installed', 'search', 'configured', 'understanding', 'architecture', 'tools', 'performing', 'patches', 'updates', 'upgrades', 'implement', 'plans', 'data', 'migration', 'installing', 'configuring', 'applied', 'tax', 'updates', 'using', 'aided', 'maintenance', 'internet', 'architecture', 'including', 'web', 'logic', 'tuxedo', 'reports', 'process', 'servers', 'possess', 'knowledge', 'peoplesoft', 'architecture', 'administration', 'design', 'implementing', 'suite', 'corporation', 'needs', 'cobol', 'installation', 'troubleshooting', 'compiling', 'cobol', 'issues', 'performed', 'integration', 'broker', 'setup', 'modules', 'worked', 'instance', 'verification', 'test', 'data', 'refresh', 'production', 'ensuring', 'data', 'integrity', 'using', 'tools', 'dddaudit', 'sysaudit', 'development', 'phases', 'helped', 'create', 'implement', 'security', 'procedures', 'databases', 'developed', 'specifications', 'performed', 'duties', 'worked', 'scheduling', 'process', 'maintenance', 'activities', 'cleaning', 'application', 'web', 'process', 'scheduler', 'servers', 'experienced', 'people', 'tool', 'upgrade', 'knowledge', 'application', 'upgrade', 'experienced', 'monitoring', 'peoplesoft', 'jobs', 'tivoli', 'job', 'scheduling', 'console', 'tool', 'creating', 'jobs', 'scheduling', 'jobs', 'requirement', 'troubleshooting', 'issues', 'training', 'employees', 'administration', 'related', 'tasks', 'handled', 'project', 'migrations', 'security', 'requests', 'work', 'orders', 'sent', 'ticketing', 'system', 'performed', 'source', 'target', 'databases', 'peoplesoft', 'experience', 'cloning', 'servers', 'cloud', 'strategies', 'based', 'features', 'includes', 'watch', 'load', 'balancers', 'skills', 'peoplesoft', 'applications', 'people', 'tools', 'version', 'application', 'designer', 'application', 'engine', 'people', 'code', 'data', 'mover', 'process', 'scheduler', 'images', 'sqr', 'query', 'xml', 'publisher', 'reporting', 'tools', 'tuxedo', 'databases', 'operating', 'work', 'experience', 'working', 'date', 'worked', 'project', 'bit', 'database', 'application', 'level', 'hrms', 'tools', 'version', 'project', 'responsibilities', 'involved']

# %% [markdown]
# ### 7.2 Counting all the Nouns and Verbs present in the Tokens of words

# %%
cv = CountVectorizer()
X = cv.fit_transform(nouns_verbs)
sum_words = X.sum(axis=0)

words_freq = [(word,sum_words[0,idx]) for word, idx in cv.vocabulary_.items()]
words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)

wd_df = pd.DataFrame(words_freq)
wd_df.columns = ['Words','Count']
wd_df[0:15]
# Out:
#            Words  Count
# 0     experience    548
# 1    application    412
# 2          using    400
# 3        reports    326
# 4        workday    313
# 5           data    309
# 6        project    309
# 7       business    262
# 8            web    250
# 9       database    240
# 10       process    234
# 11        server    223
# 12        worked    220
# 13      involved    194
# 14  integrations    189

# %% [markdown]
# ### 7.3 Visualizing the Result of Top 20 Nouns and Verbs most Frequently

# %%
fig, axe = plt.subplots(1,1, figsize=(10,7), dpi=200)
ax = sns.barplot(x= wd_df['Count'].head(20), y= wd_df.Words.head(20), data= wd_df, ax = axe,
            label= 'Total Pofile Category : {}'.format(len(resume_data.Category.unique())))

axe.set_xlabel('Frequency', size=16,fontweight= 'bold')
axe.set_ylabel('Words', size=16, fontweight= 'bold')
plt.xticks(rotation = 0)
plt.legend(loc='best', fontsize= 'x-large')
plt.title('Top 25 Most used Nouns and Verbs in Resumes', fontsize= 18, fontweight= 'bold')
rcParams = {'xtick.labelsize':'14','ytick.labelsize':'14','axes.labelsize':'16'}

for i in ax.containers:
    ax.bar_label(i,color = 'black', fontweight = 'bold', fontsize= 12)

pylab.rcParams.update(rcParams)
fig.tight_layout()
plt.show()

# %%
text = " ".join(cat for cat in wd_df.Words) # Creating the text variable

word_cloud = WordCloud(width=1000, height=800, random_state=10, background_color="black",
                       colormap="Pastel1", collocations=False, stopwords=STOPWORDS).generate(text)

plt.figure(figsize=(10,7), dpi=800) # Display the generated Word Cloud
plt.title('Most used Nouns and Verbs in Resumes', fontsize= 15, fontweight= 'bold')
plt.imshow(word_cloud)
plt.axis("off")
plt.show()

# %%
import spacy
import pandas as pd

# Load spaCy English model
nlp = spacy.load("en_core_web_sm")

# Load the cleaned resume data
resume_df = pd.read_csv("/content/Cleaned_Resumes.csv")

# Function to extract potential skills (nouns and verbs) from resume text
def extract_skills(text):
    doc = nlp(text)
    return [token.text.lower() for token in doc if token.pos_ in ("NOUN", "VERB") and not token.is_stop]

# Apply the function to the Resume_Details column
resume_df['Extracted_Skills'] = resume_df['Resume_Details'].apply(extract_skills)

# Flatten and deduplicate all skills
all_skills = sorted(set(skill for skills in resume_df['Extracted_Skills'] for skill in skills))

# Save skills to a CSV file
skills_df = pd.DataFrame({"Skill": all_skills})

print("Skills extracted and saved to skills.csv.")
skills_df.to_csv("skills.csv", index=False)
# Out:
# Skills extracted and saved to skills.csv.

# %%
## The End
